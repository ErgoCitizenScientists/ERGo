# %%
import importlib

import erg
import erg.plotting as plotting

importlib.reload(erg)
importlib.reload(erg.plotting)
''' good source for colormaps
https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
'''
# new: r'C:\Users\danpo\Documents\BYB\BYB_Recording_2019-07-01_18.53.08.wav'
# old: r'C:\Users\danpo\Documents\BYB\BYB_Recording_2019-06-17_18.12.54.wav'
# fake data:
# r'C:\Users\danpo\Documents\BYB\fake_ergs\BYB_Recording_2019-07-01_18.28.58.wav'
wf_fake = r'C:\Users\danpo\Documents\BYB\fake_ergs\BYB_Recording_2019-07-01_18.28.58.wav'
wf_real = r'C:\Users\danpo\Documents\BYB\BYB_Recording_2019-07-08_12.06.15.wav'

# %%
erg_fake = erg.ERG(wf_fake)
p = plotting.Plotting(erg_fake)
print('These are fake ergs:')
p.quick(whole_trial=True)

# %%
print("fake again!")
p.bode()
# Out:
# fake again!
# C:\Users\danpo\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:3099: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=512.0, right=512.0
#   self.set_xlim(upper, lower, auto=None)

# %%
erg_real = erg.ERG(wf_real)
p = plotting.Plotting(erg_real)
print('These are real ones:')
p.bode()

p.quick(whole_trial=True)
# Out:
# These are real ones:
# C:\Users\danpo\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:3099: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=512.0, right=512.0
#   self.set_xlim(upper, lower, auto=None)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-17-7bcae4d2a76e> in <module>
#       4 p.bode()
#       5
# ----> 6 p.quick(whole_trial=True)
#
# ~\Google Drive\ERGo\erg\plotting\__init__.py in quick(self, normalize, show_all, whole_trial)
#     118
#     119             trials_list = messages[key]
# --> 120             for timestamps_list in trials_list:
#     121
#     122                 freq = self.ergram.get_frequency(key)
#
# ~\Google Drive\ERGo\erg\__init__.py in get_color(self, key)
#      98             return 'blue'
#      99         elif color_index not in [9, 10, 11, 12, 13]:
# --> 100             raise Exception("invalid color_index {}".format(color_index))
#     101
#     102
#
# Exception: invalid color_index 6

# %%
# %load_ext autoreload
# %autoreload 2
import sys

# Mount the Google Drive and load the modules
from google.colab import drive
drive.mount('/content/gdrive')
PROJECT_PATH = '/content/gdrive/My Drive/BYB Projects/BYB 2019 Fellows/Data/Insect ERGs/ERGo/erg'
sys.path.append(PROJECT_PATH)

import erg
import erg.plotting as plotting

''' good source for colormaps
https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
'''

# new: r'C:\Users\danpo\Documents\BYB\BYB_Recording_2019-07-01_18.53.08.wav'
# old: r'C:\Users\danpo\Documents\BYB\BYB_Recording_2019-06-17_18.12.54.wav'
# fake data:
# r'C:\Users\danpo\Documents\BYB\fake_ergs\BYB_Recording_2019-07-01_18.28.58.wav'
# real data
wf = r'C:\Users\danpo\Documents\BYB\fake_ergs\BYB_Recording_2019-07-01_18.28.58.wav'
erg = erg.ERG(wf)
p = plotting.Plotting(erg)
p.quick(whole_trial=True)
